# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"]= "-1"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#start with single fully connected neural layer as encoder and decoder
from keras.models import Sequential, Model #inear stack of neural network layers
from keras.layers import Dense, Dropout, Activation, Flatten, Input, UpSampling2D #core layers
from keras.layers import Convolution2D, MaxPooling2D, Conv2D, Reshape, Conv2DTranspose #convolutional layers to help efficiently train on image data
import cv2
import numpy as np
import matplotlib
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from matplotlib import image
from sklearn.model_selection import train_test_split
import glob
#from os import listdir
import imageio
import re
import skimage
from skimage import measure
import skimage.measure as measure
#from skimage.measure import structural_similarity as ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2
#from skimage.measure import compare_ssim
import argparse
#import imutils
import cv2
import random
from platform import python_version
import keras

# %% [markdown]
# Setting data path for data: both contour directory and original scan path. array of scans and contours - resized for use for further code - expand dimesions for last channel = colour

# %%
all_scans=[]
all_lines=[]
#reading in testing data from ADID-UNET (Raj 2021)
img_dir="/content/drive/MyDrive/Colab Notebooks/ADID-UNET"
data_path=os.path.join(img_dir,'test_inputs_images/Test_Image_*g')
files=glob.glob(data_path)

cont_dir="/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_ground truth/" 

mysize=128
dim = (mysize, mysize)
print(files)
#augmenting data for a larger dataset
for f1 in files:
    readscan=np.asarray(cv2.resize((image.imread(f1)),dim,interpolation=cv2.INTER_AREA))
    all_scans.append(readscan)
    i=re.split('_|.png',f1)[4]
    readlines=np.asarray(cv2.resize((image.imread(cont_dir+ 'Test_Image_'+i+'_OriginalMask.png')),dim,interpolation=cv2.INTER_AREA))
    all_lines.append(readlines)
    #data augmentation
    all_scans.append(np.flipud(readscan))
    all_lines.append(np.flipud(readlines))
    all_scans.append(np.fliplr(readscan))
    all_lines.append(np.fliplr(readlines))
    all_scans.append(np.flipud(np.fliplr(readscan)))
    all_lines.append(np.flipud(np.fliplr(readlines)))



#expand dims ensures that the last channel is the colour (1)
X=np.expand_dims(np.rollaxis(np.dstack(all_scans),-1),3)
Y=np.expand_dims(np.rollaxis(np.dstack(all_lines),-1),3)
#print(all_scans)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_51.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_199.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_86.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_172.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_53.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_84.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_85.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_92.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_170.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_90.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_91.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_47.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_198.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_52.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_46.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_158.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_164.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_167.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_166.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_173.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_9.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_81.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_110.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_175.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_42.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_78.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_30.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_56.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_93.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_87.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_97.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_104.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_79.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_57.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_50.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_176.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_96.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_200.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_43.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_165.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_94.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_54.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_177.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images/Test_Image_18.png', '/content/drive/MyDrive/Colab Notebooks/ADID-UNET/test_inputs_images ...

# %% [markdown]
# Writing the autoencoder: input image with set shape, fed through 3 convolutional layers and encoded layer with maxpooling function and activation ReLU. Decoder includes 3 transposed convolutional layers (ReLU) with a decoded layer (activation sigmoid) - all padding = same
# optimizer- adam, loss - binary_crossentropy

# %%
len(X)
new_X=[]
new_Y=[]
randnums= np.random.randint(1,800,600)

for i in randnums:
  new_X.append(X[i])
  new_Y.append(Y[i])

newer_X=np.array(new_X)
newer_Y=np.array(new_Y)

# %%
 #with strategy.scope():

input_img=Input(shape=(X[0].shape))
#encoded layers
x = Conv2D(128,(3,3),activation='relu',padding='same')(input_img)
 
x = Conv2D(64,(3,3),activation='relu',padding='same')(x)
 
x = Conv2D(32,(3,3),activation='relu',padding='same')(x)
encoded = MaxPooling2D((2,2),padding='same')(x)

    #decoded layers
x = Conv2DTranspose(32,(3,3), strides=2, activation='relu',padding='same')(encoded)
   
x = Conv2DTranspose(64,(3,3), activation='relu',padding='same')(x)
   
x = Conv2DTranspose(128,(3,3), activation='relu',padding='same')(x)   
  
decoded = Conv2DTranspose(1,(3,3),activation='sigmoid',padding='same')(x)

#defining model, compliling and summary
autoencoder = Model(input_img,decoded)
autoencoder.compile(optimizer='adam',loss='binary_crossentropy')
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 128)     1280
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      73792
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)      18464
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_transpose (Conv2DTra  (None, 128, 128, 32)     9248
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 128, 128, 64)     18496
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 128, 128, 128)    73856
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 128, 128, 1)      1153
#  ranspose)
#
# =================================================================
# Total params: 196,289
# Trainable params: 196,289
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Setting test and train data split with 80/20 split

# %%
x_train, x_test = train_test_split(newer_X, test_size=0.2, random_state=28)
y_train, y_test = train_test_split(newer_Y, test_size=0.2, random_state=28)

# %%
#training model
history = autoencoder.fit(x_train, y_train,
                          batch_size=2,
                          epochs=60,
                          shuffle=True,
                          verbose=1,
                          validation_data=(x_test, y_test))
# Out:
# Epoch 1/60
# 240/240 [==============================] - 12s 13ms/step - loss: 0.1275 - val_loss: 0.1023
# Epoch 2/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0996 - val_loss: 0.0939
# Epoch 3/60
# 240/240 [==============================] - 3s 12ms/step - loss: 0.0821 - val_loss: 0.0917
# Epoch 4/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0768 - val_loss: 0.0812
# Epoch 5/60
# 240/240 [==============================] - 3s 12ms/step - loss: 0.0636 - val_loss: 0.0674
# Epoch 6/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0629 - val_loss: 0.0604
# Epoch 7/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0553 - val_loss: 0.0706
# Epoch 8/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0525 - val_loss: 0.0702
# Epoch 9/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0525 - val_loss: 0.0546
# Epoch 10/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0455 - val_loss: 0.0486
# Epoch 11/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0440 - val_loss: 0.0462
# Epoch 12/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0440 - val_loss: 0.0463
# Epoch 13/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0401 - val_loss: 0.0456
# Epoch 14/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0400 - val_loss: 0.0492
# Epoch 15/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0408 - val_loss: 0.0577
# Epoch 16/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0401 - val_loss: 0.0423
# Epoch 17/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0368 - val_loss: 0.0402
# Epoch 18/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0390 - val_loss: 0.0452
# Epoch 19/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0359 - val_loss: 0.0507
# Epoch 20/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0383 - val_loss: 0.0396
# Epoch 21/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0358 - val_loss: 0.0405
# Epoch 22/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0375 - val_loss: 0.0403
# Epoch 23/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0354 - val_loss: 0.0394
# Epoch 24/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0346 - val_loss: 0.0381
# Epoch 25/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0329 - val_loss: 0.0361
# Epoch 26/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0326 - val_loss: 0.0388
# Epoch 27/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0321 - val_loss: 0.0386
# Epoch 28/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0323 - val_loss: 0.0360
# Epoch 29/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0320 - val_loss: 0.0423
# Epoch 30/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0328 - val_loss: 0.0367
# Epoch 31/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0305 - val_loss: 0.0359
# Epoch 32/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0297 - val_loss: 0.0347
# Epoch 33/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0315 - val_loss: 0.0392
# Epoch 34/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0289 - val_loss: 0.0345
# Epoch 35/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0291 - val_loss: 0.0396
# Epoch 36/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0292 - val_loss: 0.0333
# Epoch 37/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0273 - val_loss: 0.0340
# Epoch 38/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0267 - val_loss: 0.0325
# Epoch 39/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0293 - val_loss: 0.0354
# Epoch 40/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0284 - val_loss: 0.0348
# Epoch 41/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0286 - val_loss: 0.0348
# Epoch 42/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0263 - val_loss: 0.0337
# Epoch 43/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0257 - val_loss: 0.0348
# Epoch 44/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0282 - val_loss: 0.0334
# Epoch 45/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0255 - val_loss: 0.0322
# Epoch 46/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0260 - val_loss: 0.0341
# Epoch 47/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0257 - val_loss: 0.0344
# Epoch 48/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0243 - val_loss: 0.0359
# Epoch 49/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0240 - val_loss: 0.0319
# Epoch 50/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0236 - val_loss: 0.0320
# Epoch 51/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0229 - val_loss: 0.0313
# Epoch 52/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0276 - val_loss: 0.0334
# Epoch 53/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0236 - val_loss: 0.0311
# Epoch 54/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0226 - val_loss: 0.0305
# Epoch 55/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0225 - val_loss: 0.0336
# Epoch 56/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0215 - val_loss: 0.0307
# Epoch 57/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0212 - val_loss: 0.0318
# Epoch 58/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0207 - val_loss: 0.0300
# Epoch 59/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0254 - val_loss: 0.0331
# Epoch 60/60
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0237 - val_loss: 0.0323

# %% [markdown]
# Give predition of test (output of autoencoder from seeing unseen images) - displaying contour, original image and predicted contour.

# %%
decoded_img = autoencoder.predict(x_test)

n=5
plt.figure(figsize=(30,10))
for i in range (1,n+1):

    #display original (CT)
    ax= plt.subplot(3,n,i)
    plt.imshow(x_test[i].reshape(mysize,mysize))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    #display prediction
    ax1=plt.subplot(3,n,i+n)
    plt.imshow(decoded_img[i].reshape(mysize,mysize))
    plt.gray()
    ax1.get_xaxis().set_visible(False)
    ax1.get_yaxis().set_visible(False)
    
    #display contour (GT)
    ax2=plt.subplot(3,n,i+2*n)
    plt.imshow(y_test[i].reshape(mysize,mysize))
    plt.gray()
    ax2.get_xaxis().set_visible(False)
    ax2.get_yaxis().set_visible(False)


plt.show()
# Out:
# 4/4 [==============================] - 2s 332ms/step

# %% [markdown]
# Produce graph to show training loss for test and training data as number of epochs increase...

# %%
#code to save prediction images as png file
for i in range (len(decoded_img)):
    Prediction=(decoded_img[i].reshape(mysize,mysize))
    predict_name = "/content/drive/MyDrive/Colab Notebooks/ADID-UNET/PredictionResults2022/AE-CNN Normal (800)/Test_Image_"+str(i+1)+"_Predict.png"
    plt.imsave(predict_name,Prediction)

# %%
#code to save Ground truth (original mask) as png
for i in range (len(decoded_img)):
    GroundTruth=(y_test[i].reshape(mysize,mysize))
    GT = "/content/drive/MyDrive/Colab Notebooks/ADID-UNET/GT/AE-CNN Normal GT (800)/Test_Image_"+str(i+1)+"_OriginalMask.png"
    plt.imsave(GT,GroundTruth)

# %%
#code to save CT scan as png
#for i in range (len(decoded_img)):
 #   CTscan=(x_test[i].reshape(mysize,mysize))
  #  CT = "/content/drive/MyDrive/Colab Notebooks/ADID-UNET/CT/Test_Image_"+str(i+1)+".png"
    #  plt.imsave(CT,CTscan)
